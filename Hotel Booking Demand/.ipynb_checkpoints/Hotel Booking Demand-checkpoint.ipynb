# %% [markdown]
# ### Hotel Booking Demand
#
# ##### The dataset was taken from Kaggle website.
#
# Please find the link and description below:
#
# https://www.kaggle.com/jessemostipak/hotel-booking-demand
#
# ##### Acknowledgements
# The data is originally from the article [Hotel Booking Demand Datasets](https://www.sciencedirect.com/science/article/pii/S2352340918315191), written by Nuno Antonio, Ana Almeida, and Luis Nunes for Data in Brief, Volume 22, February 2019.
#
# The data was downloaded and cleaned by Thomas Mock and Antoine Bichat for [#TidyTuesday during the week of February 11th, 2020](https://github.com/rfordatascience/tidytuesday/blob/master/data/2020/2020-02-11/readme.md).
#
# ### Abstract
#
# This data article describes two datasets with hotel demand data.
# One of the hotels (H1) is a resort hotel and the other is a city hotel (H2).
# Both datasets share the same structure, with 31 variables describing the 40,060 observations of H1 and 79,330 observations of H2.
# Each observation represents a hotel booking.
# Both datasets comprehend bookings due to arrive between the 1st of July of 2015 and the 31st of August 2017, including bookings that effectively arrived and bookings that were canceled.
# Since this is hotel real data, all data elements pertaining hotel or costumer identification were deleted.
# Due to the scarcity of real business data for scientific and educational purposes, these datasets can have an important role for research and education in revenue management, machine learning, or data mining, as well as in other fields.
#
# #### Questions to be answered
#
# * Where do guests come from?
# * How much do guests pay for a room per night?
# * How the price changes depending on the month of the year?
# * When usually guests book a hotel room?
# * How long do guests stay at hotels?
# * Which rooms do guests prefer?
# * Preferred days of stay
# * How many bookings were cancelled?
# * Which month has the highest number of cancellations?
#
# #### Predictions
# Predictions of cancellation could help a hotel to plan and manage their assets.

# %% [markdown]
# https://www.kaggle.com/marcuswingen/eda-of-bookings-and-ml-to-predict-cancelations
# https://www.kaggle.com/mayureedeshmukh/hotel-booking-demand-first-eda-project
# https://www.kaggle.com/tanetboss/random-forest-simply-visualization
# https://www.kaggle.com/selvarasuk2/hotel-booking-best-prediction-model/notebook
# https://www.kaggle.com/amarloni/eda-best-regression-data-visualization

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
db = pd.read_csv('hotel_bookings.csv')

# %%
db.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
db.shape
# Out:
# (119390, 32)

# %%
# let's check the hotel column

db['hotel'].value_counts()
# Out:
# City Hotel      79330
# Resort Hotel    40060
# Name: hotel, dtype: int64

# %% [markdown]
# Let's visualize the Hotels that we have.

# %%
plt.rcParams['figure.figsize'] = 5,5
labels = db['hotel'].value_counts().index.tolist()
sizes = db['hotel'].value_counts().tolist()
explode = (0, 0.2)

plt.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%', shadow=False, startangle=30)
plt.axis('equal')
plt.tight_layout()
plt.title("The Hotels", fontdict=None, position= [0.48,1], size = 'large')
plt.show()

# %%
# Let's find where guests come from.
db.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
db['country'].value_counts()
# Out:
# PRT    48590
# GBR    12129
# FRA    10415
# ESP     8568
# DEU     7287
#        ...
# MLI        1
# DMA        1
# SLE        1
# LCA        1
# CYM        1
# Name: country, Length: 177, dtype: int64
